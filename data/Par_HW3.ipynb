# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/726 Parallel/problem_three.csv')
data_3
# Out:
#             n      bc  num_threads  mergesort_time  stl_sort_time   speedup
# 0     1000000       1            8       72.130400       0.168719  0.002339
# 1     1000000       3            8       35.536700       0.169242  0.004762
# 2     1000000       5            8       17.361400       0.168383  0.009699
# 3     1000000       7            8       15.207300       0.168460  0.011078
# 4     1000000       9            8        8.409090       0.168422  0.020029
# ...       ...     ...          ...             ...            ...       ...
# 5045  1000000  499600            8        0.046153       0.166076  3.598390
# 5046  1000000  499700            8        0.045749       0.167509  3.661490
# 5047  1000000  499800            8        0.045691       0.167400  3.663750
# 5048  1000000  499900            8        0.046161       0.167451  3.627580
# 5049  1000000  500000            8        0.084952       0.167300  1.969340
#
# [5050 rows x 6 columns]

# %%
fig = plt.figure(figsize=(10, 10))              
x_label = data_3['bc']
y_label = data_3['speedup']
plt.plot(x_label, y_label, color = 'r',linewidth=1.0,linestyle=':')  
plt.title("Speedup & bc")                 
plt.ylabel("speedup")            
plt.xlabel("bc")            #
plt.show()

# %%
data_5 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/726 Parallel/problem_five.csv')
data_5
# Out:
#            n        bc  num_threads  mergesort_time  stl_sort_time    speedup  \
# 0   16777216  16777216            1        2.949870        2.94720   0.999095
# 1   16777216   8388608            2        1.555820        2.94817   1.894930
# 2   16777216   5592405            3        1.492200        2.94985   1.976850
# 3   16777216   4194304            4        0.792704        2.95967   3.733630
# 4   16777216   3355443            5        0.783951        2.94456   3.756050
# 5   16777216   2796202            6        0.795151        2.94551   3.704340
# 6   16777216   2396745            7        0.777089        2.94695   3.792290
# 7   16777216   2097152            8        0.451219        2.97180   6.586150
# 8   16777216   1864135            9        0.576196        2.95456   5.127700
# 9   16777216   1677721           10        0.425173        2.95100   6.940690
# 10  16777216   1525201           11        0.425820        2.94617   6.918810
# ...

# %%
fig = plt.figure(figsize=(20, 20))  
##########################
x_label = data_5['bc']  
y_label = data_5['speedup']     
plt.subplot(2,2,1)         
plt.plot(x_label, y_label, color = 'r',linewidth=1.0,linestyle=':')  
plt.title("Speedup & bc")                 
plt.ylabel("speedup")            
plt.xlabel("bc")                         
#########################
x_label = data_5['bc']  
y_label = data_5['efficiency']     
plt.subplot(2,2,2)         
plt.plot(x_label, y_label, color = 'b',linewidth=1.0,linestyle=':')  
plt.title("Efficiency & bc")                 
plt.ylabel("efficiency'")            
plt.xlabel("bc")                 
##########################
x_label = data_5['num_threads']  
y_label = data_5['speedup']     
plt.subplot(2,2,3)         
plt.plot(x_label, y_label, color = 'r',linewidth=1.0,linestyle=':')
plt.xticks(np.arange(1, 45, 1), rotation=60)
plt.title("Speedup & num_threads")                 
plt.ylabel("speedup")            
plt.xlabel("num_threads")                         
#########################
x_label = data_5['num_threads']  
y_label = data_5['efficiency']     
plt.subplot(2,2,4)         
plt.plot(x_label, y_label, color = 'b',linewidth=1.0,linestyle=':')
plt.xticks(np.arange(1, 45, 1), rotation=60) 
plt.title("Efficiency & num_threads")                 
plt.ylabel("efficiency")            
plt.xlabel("num_threads")            
plt.show()
